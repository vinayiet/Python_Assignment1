# %%
# Why do we need to visualise the data ?
# For Clearly understanding the dataset.
# To Finding the pattern from the given and trend 
# list [1,2,3,4,100] -> outlier (To detect the anamolies)

# %%
# !pip install matplotlib

# %%
# Importing the matplotlib library..
import matplotlib.pyplot as plt

# %%
import pandas as pd 
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

# %%
# We use the scatter plot for plotting the x , y points  (we basically finds the relation ship among two variables)

plt.scatter(x,y)
