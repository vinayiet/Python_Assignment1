# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading the Dataset using Pandas

# %%
df = pd.read_csv('Travel.csv')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.tail()
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 4883  Small Business    Male                       3                5.0
# 4884        Salaried    Male                       4                5.0
# 4885        Salaried  Female                       4                4.0
# 4886  Small Business    Male                       3                4.0
# 4887        Salaried    Male                       4                4.0
#
# ...

# %%
df.sample(5)
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 731       200731          1  20.0     Self Enquiry         1             17.0
# 4138      204138          0  32.0  Company Invited         1              7.0
# 2465      202465          1  37.0     Self Enquiry         3             16.0
# 2862      202862          0  27.0     Self Enquiry         1             30.0
# 1000      201000          0  52.0     Self Enquiry         1             14.0
#
#           Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 731   Small Business  Female                       3                4.0
# 4138  Small Business    Male                       3                6.0
# 2465        Salaried    Male                       3                5.0
# 2862        Salaried  Female                       3                4.0
# 1000        Salaried  Female                       2                3.0
#
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
categorical_col = df.select_dtypes(include=['object'])
num_cols = df.select_dtypes(include=['int', 'float'])

# %%
num_cols.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# CityTier                      0
# DurationOfPitch             251
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# PreferredPropertyStar        26
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# MonthlyIncome               233
# dtype: int64

# %%
df['Age'].isna().sum()
# Out:
# 226

# %%
df['Age']= df['Age'].fillna(df['Age'].mean())

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
# countplot is basically used for the 
sns.countplot(x=df['TypeofContact'], data=df )
# Out:
# <Axes: xlabel='TypeofContact', ylabel='count'>

# %%
df['TypeofContact'] = df['TypeofContact'].fillna('Self Enquiry')

# %%
df['TypeofContact'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
sns.boxplot(x=df['DurationOfPitch'].dropna(), data= df)
# Out:
# <Axes: xlabel='DurationOfPitch'>

# %%
# Since the feature duration of the column contains the outliers 
# so we will impute with median

df['DurationOfPitch'] = df['DurationOfPitch'].fillna(df['DurationOfPitch'].median())

# %%
df.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch               0
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
sns.boxplot(x=df['NumberOfFollowups'], data=df)
# Out:
# <Axes: xlabel='NumberOfFollowups'>

# %%
sns.countplot(x=df['NumberOfFollowups'], data=df)
# Out:
# <Axes: xlabel='NumberOfFollowups', ylabel='count'>

# %%
# The above countplot shows the frequency of the Number of follow up 
df['NumberOfFollowups'] = df['NumberOfFollowups'].fillna(df['NumberOfFollowups'].median())

# %%
df.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch               0
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups             0
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['PreferredPropertyStar'].unique()
# Out:
# array([ 3.,  4.,  5., nan])

# %%
sns.countplot(x=df['PreferredPropertyStar'], data=df)
# Out:
# <Axes: xlabel='PreferredPropertyStar', ylabel='count'>

# %%
df['PreferredPropertyStar'] = df['PreferredPropertyStar'].fillna(3.0)

# %%
df.isna().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
df['NumberOfTrips'].unique()
# Out:
# array([ 1.,  2.,  7.,  5.,  6.,  3.,  4., 19., 21.,  8., nan, 20., 22.])

# %%
df['NumberOfTrips'] = df['NumberOfTrips'].fillna(df['NumberOfTrips'].median())

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %%
df['NumberOfChildrenVisiting'].unique()
# Out:
# array([ 0.,  2.,  1., nan,  3.])

# %%
sns.countplot(x=df['NumberOfChildrenVisiting'], data=df )
# Out:
# <Axes: xlabel='NumberOfChildrenVisiting', ylabel='count'>

# %%
df['NumberOfChildrenVisiting'] = df['NumberOfChildrenVisiting'].fillna(1.0)

# %%
sns.boxplot(x=df['MonthlyIncome'], data=df)
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].fillna(df['MonthlyIncome'].median())

# %%
df.head()
# Out:
#    CustomerID  ProdTaken        Age    TypeofContact  CityTier  \
# 0      200000          1  41.000000     Self Enquiry         3
# 1      200001          0  49.000000  Company Invited         1
# 2      200002          1  37.000000     Self Enquiry         1
# 3      200003          0  33.000000  Company Invited         1
# 4      200004          0  37.622265     Self Enquiry         1
#
#    DurationOfPitch      Occupation  Gender  NumberOfPersonVisiting  \
# 0              6.0        Salaried  Female                       3
# 1             14.0        Salaried    Male                       3
# 2              8.0     Free Lancer    Male                       3
# 3              9.0        Salaried  Female                       2
# 4              8.0  Small Business    Male                       2
#
#    NumberOfFollowups ProductPitched  PreferredPropertyStar MaritalStatus  \
# 0                3.0         Deluxe                    3.0        Single
# ...

# %%
sns.lineplot(x=df['Age'], y=df['MonthlyIncome'], data=df)
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x=df['Designation'], y=df['MonthlyIncome'], data=df)
# Out:
# <Axes: xlabel='Designation', ylabel='MonthlyIncome'>

# %%
corr = df.corr(numeric_only=True)


plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
print('hello')
# Out:
# 19.833333333333332
